# %%
pip install --upgrade google-genai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai
from google.genai import types
import base64

def generate():
  client = genai.Client(
      vertexai=True,
      project="ai-prediction-train-01",
      location="us-central1",
  )

  image1 = types.Part.from_uri(
      file_uri="gs://cloud-ai-platform-e93b5f2e-13b4-4e69-a0f0-4676c3312f9b/Departure Board Image.png",
      mime_type="image/png",
  )
  text1 = types.Part.from_text(text="""Read the text in the image.
Parse the time and city in this image into a list with two columns: time and city.
Calculate the percentage of the flights to different continents. Format your response in HTML""")

  model = "gemini-2.0-flash-001"
  contents = [
    types.Content(
      role="user",
      parts=[
        image1,
        text1
      ]
    )
  ]
  generate_content_config = types.GenerateContentConfig(
    temperature = 1,
    top_p = 0.95,
    max_output_tokens = 8192,
    response_modalities = ["TEXT"],
  )

  for chunk in client.models.generate_content_stream(
    model = model,
    contents = contents,
    config = generate_content_config,
    ):
    print(chunk.text, end="")

generate()
# Out:
# Here's the parsed information and the continent breakdown:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Flight Information</title>
# </head>
# <body>
#
# <h2>Flight Schedule</h2>
#
# <table border="1">
#   <thead>
#     <tr>
#       <th>Time</th>
#       <th>City</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10:50</td>
#       <td>Moscow/SUO</td>
#     </tr>
#     <tr>
#       <td>11:05</td>
#       <td>Edinburgh</td>
#     </tr>
#     <tr>
#       <td>11:05</td>
#       <td>London/LHR</td>
#     </tr>
#     <tr>
#       <td>11:10</td>
#       <td>Bucharest/OTP</td>
#     </tr>
#     <tr>
#       <td>11:30</td>
#       <td>Kiev/Borispol</td>
#     </tr>
#     <tr>
#       <td>11:45</td>
#       <td>East Midlands</td>
#     </tr>
#      <tr>
#       <td>12:15</td>
#       <td>Sofia</td>
#     </tr>
#     <tr>
#       <td>12:30</td>
#       <td>London/LGW</td>
#     </tr>
#    <tr>
#       <td>12:30</td>
#       <td>Newcastle</td>
#     </tr>
#     <tr>
# ...
